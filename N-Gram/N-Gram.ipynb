# %%
from collections import Counter, namedtuple
import json
import re

# %%
DATASET_DIR = './WebNews.json'
with open(DATASET_DIR, encoding = 'utf8') as f:
    dataset = json.load(f)

# %%
seg_list = list(map(lambda d: d['detailcontent'], dataset))
rule = re.compile(r"[^\u4e00-\u9fa5]")
seg_list = [rule.sub('', seg) for seg in seg_list]

# %%
def ngram(documents, N=2):
    ngram_prediction = dict()
    total_grams = list()
    words = list()
    Word = namedtuple('Word', ['word', 'prob'])

    for doc in documents:
        split_words = ['<s>'] + list(doc) + ['</s>']
        # 計算分子
        [total_grams.append(tuple(split_words[i:i+N])) for i in range(len(split_words)-N+1)]
        # 計算分母
        [words.append(tuple(split_words[i:i+N-1])) for i in range(len(split_words)-N+2)]
        
    total_word_counter = Counter(total_grams)
    word_counter = Counter(words)
    
    for key in total_word_counter:
        word = ''.join(key[:N-1])
        if word not in ngram_prediction:
            ngram_prediction.update({word: set()})
            
        next_word_prob = total_word_counter[key]/word_counter[key[:N-1]]
        w = Word(key[-1], '{:.3g}'.format(next_word_prob))
        ngram_prediction[word].add(w)
        
    return ngram_prediction

# %%
tri_prediction = ngram(seg_list, N=3)
for word, ng in tri_prediction.items():
    tri_prediction[word] = sorted(ng, key=lambda x: x.prob, reverse=True)

# %%
tri_prediction
# Out:
# {'<s>出': [Word(word='席', prob='1')],
#  '出席': [Word(word='活', prob='0.23'),
#   Word(word='桃', prob='0.151'),
#   Word(word='</s>', prob='0.139'),
#   Word(word='年', prob='0.0629'),
#   Word(word='中', prob='0.0207'),
#   Word(word='典', prob='0.019'),
#   Word(word='國', prob='0.0141'),
#   Word(word='大', prob='0.0132'),
#   Word(word='八', prob='0.0124'),
#   Word(word='新', prob='0.0116'),
#   Word(word='財', prob='0.00993'),
#   Word(word='記', prob='0.00993'),
#   Word(word='龍', prob='0.00993'),
#   Word(word='視', prob='0.00911'),
#   Word(word='說', prob='0.00828'),
#   Word(word='第', prob='0.00828'),
#   Word(word='平', prob='0.00828'),
#   Word(word='頒', prob='0.00745'),
#   Word(word='開', prob='0.00662'),
#   Word(word='市', prob='0.00579'),
#   Word(word='台', prob='0.00579'),
#   Word(word='蘆', prob='0.00497'),
#   Word(word='觀', prob='0.00497'),
#   Word(word='全', prob='0.00497'),
#   Word(word='啟', prob='0.00414'),
#   Word(word='表', prob='0.00414'),
#   Word(word='農', prob='0.00414'),
#   Word(word='南', prob='0.00414'),
#   Word(word='音', prob='0.00414'),
#   Word(word='慈', prob='0.00414'),
#   Word(word='楊', prob='0.00331'),
#   Word(word='交', prob='0.00331'),
#   Word(word='今', prob='0.00331'),
#   Word(word='三', prob='0.00331'),
#   Word(word='宏', prob='0.00331'),
#   Word(word='演', prob='0.00248'),
#   Word(word='世', prob='0.00248'),
#   Word(word='天', prob='0.00248'),
#   Word(word='元', prob='0.00248'),
#   Word(word='論', prob='0.00248'),
#   Word(word='龜', prob='0.00248'),
#   Word(word='青', prob='0.00248'),
#   Word(word='夏', prob='0.00248'),
#   Word(word='捐', prob='0.00248'),
#   Word(word='關', prob='0.00248'),
#   Word(word='嘉', prob='0.00248'),
#   Word(word='閩', prob='0.00248'),
#   Word(word='曹', prob='0.00166'),
#   Word(word='竹', prob='0.00166'),
#   Word(word='華', prob='0.00166'),
#   Word(word='埤', prob='0.00166'),
#   Word(word='率', prob='0.00166'),
#   Word(word='乙', prob='0.00166'),
#   Word(word='神', prob='0.00166'),
#   Word(word='環', prob='0.00166'),
#   Word(word='川', prob='0.00166'),
#   Word(word='慰', prob='0.00166'),
#   Word(word='他', prob='0.00166'),
#   Word(word='土', prob='0.00166'),
#   Word(word='家', prob='0.00166'),
#   Word(word='亞', prob='0.00166'),
#   Word(word='的', prob='0.00166'),
#   Word(word='慶', prob='0.00166'),
#   Word(word='聯', prob='0.00166'),
#   Word(word='動', prob='0.00166'),
#   Word(word='直', prob='0.00166'),
#   Word(word='思', prob='0.00166'),
#   Word(word='線', prob='0.00166'),
#   Word(word='五', prob='0.00166'),
#   Word(word='教', prob='0.00166'),
#   Word(word='行', prob='0.00166'),
#   Word(word='樂', prob='0.00166'),
#   Word(word='共', prob='0.00166'),
#   Word(word='復', prob='0.00166'),
#   Word(word='臺', prob='0.00166'),
#   Word(word='會', prob='0.00166'),
#   Word(word='幸', prob='0.00166'),
#   Word(word='永', prob='0.00166'),
#   Word(word='社', prob='0.00166'),
#   Word(word='心', prob='0.00166'),
#   Word(word='紀', prob='0.00166'),
#   Word(word='發', prob='0.00166'),
#   Word(word='癸', prob='0.000828'),
#   Word(word='海', prob='0.000828'),
#   Word(word='好', prob='0.000828'),
#   Word(word='跟', prob='0.000828'),
#   Word(word='崙', prob='0.000828'),
#   Word(word='虎', prob='0.000828'),
#   Word(word='簽', prob='0.000828'),
#   Word(word='延', prob='0.000828'),
#   Word(word='讓', prob='0.000828'),
#   Word(word='情', prob='0.000828'),
#   Word(word='愛', prob='0.000828'),
#   Word(word='馬', prob='0.000828'),
#   Word(word='鄭', prob='0.000828'),
#   Word(word='本', prob='0.000828'),
#   Word(word='金', prob='0.000828'),
#   Word(word='據', prob='0.000828'),
#   Word(word='參', prob='0.000828'),
#   Word(word='跨', prob='0.000828'),
#   Word(word='前', prob='0.000828'),
#   Word(word='晚', prob='0.000828'),
#   Word(word='揭', prob='0.000828'),
#   Word(word='宣', prob='0.000828'),
#   Word(word='小', prob='0.000828'),
#   Word(word='美', prob='0.000828'),
#   Word(word='慢', prob='0.000828'),
#   Word(word='拜', prob='0.000828'),
#   Word(word='但', prob='0.000828'),
#   Word(word='秋', prob='0.000828'),
#   Word(word='港', prob='0.000828'),
#   Word(word='多', prob='0.000828'),
#   Word(word='綠', prob='0.000828'),
#   Word(word='恩', prob='0.000828'),
#   Word(word='閃', prob='0.000828'),
#   Word(word='歐', prob='0.000828'),
#   Word(word='企', prob='0.000828'),
#   Word(word='廈', prob='0.000828'),
#   Word(word='藝', prob='0.000828'),
#   Word(word='佛', prob='0.000828'),
#   Word(word='同', prob='0.000828'),
#   Word(word='團', prob='0.000828'),
#   Word(word='客', prob='0.000828'),
#   Word(word='資', prob='0.000828'),
#   Word(word='各', prob='0.000828'),
#   Word(word='以', prob='0.000828'),
#   Word(word='電', prob='0.000828'),
#   Word(word='點', prob='0.000828'),
#   Word(word='落', prob='0.000828'),
#   Word(word='機', prob='0.000828'),
#   Word(word='再', prob='0.000828'),
#   Word(word='角', prob='0.000828'),
#   Word(word='水', prob='0.000828'),
#   Word(word='公', prob='0.000828'),
#   Word(word='置', prob='0.000828'),
#   Word(word='運', prob='0.000828'),
#   Word(word='郵', prob='0.000828'),
#   Word(word='由', prob='0.000828'),
#   Word(word='浪', prob='0.000828'),
#   Word(word='保', prob='0.000828'),
#   Word(word='百', prob='0.000828'),
#   Word(word='明', prob='0.000828'),
#   Word(word='探', prob='0.000828'),
#   Word(word='聲', prob='0.000828'),
#   Word(word='專', prob='0.000828'),
#   Word(word='講', prob='0.000828'),
#   Word(word='志', prob='0.000828'),
#   Word(word='科', prob='0.000828'),
#   Word(word='司', prob='0.000828'),
#   Word(word='研', prob='0.000828'),
#   Word(word='油', prob='0.000828'),
#   Word(word='儀', prob='0.000828'),
#   Word(word='何', prob='0.000828'),
#   Word(word='緯', prob='0.000828'),
#   Word(word='福', prob='0.000828'),
#   Word(word='范', prob='0.000828'),
#   Word(word='績', prob='0.000828'),
#   Word(word='石', prob='0.000828'),
#   Word(word='日', prob='0.000828'),
#   Word(word='人', prob='0.000828'),
#   Word(word='用', prob='0.000828'),
#   Word(word='戀', prob='0.000828'),
#   Word(word='庇', prob='0.000828'),
#   Word(word='治', prob='0.000828'),
#   Word(word='通', prob='0.000828'),
#   Word(word='草', prob='0.000828'),
#   Word(word='黃', prob='0.000828'),
#   Word(word='超', prob='0.000828'),
#   Word(word='見', prob='0.000828'),
#   Word(word='因', prob='0.000828'),
#   Word(word='噶', prob='0.000828'),
#   Word(word='饗', prob='0.000828'),
#   Word(word='汽', prob='0.000828'),
#   Word(word='厝', prob='0.000828'),
#   Word(word='移', prob='0.000828'),
#   Word(word='閉', prob='0.000828'),
#   Word(word='航', prob='0.000828'),
#   Word(word='櫻', prob='0.000828'),
#   Word(word='德', prob='0.000828'),
#   Word(word='北', prob='0.000828'),
#   Word(word='城', prob='0.000828'),
#   Word(word='內', prob='0.000828'),
#   Word(word='歡', prob='0.000828'),
#   Word(word='聖', prob='0.000828'),
#   Word(word='異', prob='0.000828'),
#   Word(word='文', prob='0.000828'),
#   Word(word='一', prob='0.000828'),
#   Word(word='溪', prob='0.000828'),
#   Word(word='基', prob='0.000828'),
#   Word(word='授', prob='0.000828'),
#   Word(word='在', prob='0.000828'),
#   Word(word='祭', prob='0.000828'),
#   Word(word='入', prob='0.000828')],
#  '席元': [Word(word='智', prob='0.667'), Word(word='生', prob='0.333')],
#  '元智': [Word(word='大', prob='0.92'),
#   Word(word='先', prob='0.04'),
#   Word(word='慧', prob='0.04')],
#  '智大': [Word(word='學', prob='1')],
#  '大學': [Word(word='校', prob='0.118'),
#   Word(word='桃', prob='0.0456'),
#   Word(word='副', prob='0.0322'),
#   Word(word='生', prob='0.0268'),
#   Word(word='合', prob='0.0268'),
#   Word(word='及', prob='0.0214'),
#   Word(word='觀', prob='0.0214'),
#   Word(word='出', prob='0.0214'),
#   Word(word='也', prob='0.0188'),
#   Word(word='成', prob='0.0188'),
#   Word(word='國', prob='0.0188'),
#   Word(word='附', prob='0.0188'),
#   Word(word='土', prob='0.0188'),
#   Word(word='的', prob='0.0161'),
#   Word(word='智', prob='0.0134'),
#   Word(word='台', prob='0.0134'),
#   Word(word='育', prob='0.0134'),
#   Word(word='簽', prob='0.0134'),
#   Word(word='在', prob='0.0107'),
#   Word(word='教', prob='0.0107'),
#   Word(word='等', prob='0.0107'),
#   Word(word='周', prob='0.0107'),
#   Word(word='優', prob='0.0107'),
#   Word(word='將', prob='0.0107'),
#   Word(word='週', prob='0.00804'),
#   Word(word='社', prob='0.00804'),
#   Word(word='於', prob='0.00804'),
#   Word(word='理', prob='0.00804'),
#   Word(word='而', prob='0.00804'),
#   Word(word='新', prob='0.00804'),
#   Word(word='提', prob='0.00804'),
#   Word(word='公', prob='0.00804'),
#   Word(word='是', prob='0.00804'),
#   Word(word='規', prob='0.00804'),
#   Word(word='永', prob='0.00804'),
#   Word(word='中', prob='0.00804'),
#   Word(word='商', prob='0.00804'),
#   Word(word='與', prob='0.00804'),
#   Word(word='農', prob='0.00804'),
#   Word(word='站', prob='0.00804'),
#   Word(word='則', prob='0.00536'),
#   Word(word='開', prob='0.00536'),
#   Word(word='地', prob='0.00536'),
#   Word(word='管', prob='0.00536'),
#   Word(word='目', prob='0.00536'),
#   Word(word='藝', prob='0.00536'),
#   Word(word='隊', prob='0.00536'),
#   Word(word='化', prob='0.00536'),
#   Word(word='進', prob='0.00536'),
#   Word(word='萬', prob='0.00536'),
#   Word(word='列', prob='0.00536'),
#   Word(word='前', prob='0.00536'),
#   Word(word='醫', prob='0.00536'),
#   Word(word='院', prob='0.00536'),
#   Word(word='通', prob='0.00536'),
#   Word(word='董', prob='0.00536'),
#   Word(word='尤', prob='0.00536'),
#   Word(word='許', prob='0.00536'),
#   Word(word='未', prob='0.00536'),
#   Word(word='創', prob='0.00536'),
#   Word(word='陳', prob='0.00268'),
#   Word(word='全', prob='0.00268'),
#   Word(word='聯', prob='0.00268'),
#   Word(word='操', prob='0.00268'),
#   Word(word='大', prob='0.00268'),
#   Word(word='無', prob='0.00268'),
#   Word(word='沒', prob='0.00268'),
#   Word(word='博', prob='0.00268'),
#   Word(word='擬', prob='0.00268'),
#   Word(word='城', prob='0.00268'),
#   Word(word='學', prob='0.00268'),
#   Word(word='高', prob='0.00268'),
#   Word(word='協', prob='0.00268'),
#   Word(word='申', prob='0.00268'),
#   Word(word='儲', prob='0.00268'),
#   Word(word='致', prob='0.00268'),
#   Word(word='每', prob='0.00268'),
#   Word(word='保', prob='0.00268'),
#   Word(word='自', prob='0.00268'),
#   Word(word='數', prob='0.00268'),
#   Word(word='黃', prob='0.00268'),
#   Word(word='輔', prob='0.00268'),
#   Word(word='為', prob='0.00268'),
#   Word(word='投', prob='0.00268'),
#   Word(word='藻', prob='0.00268'),
#   Word(word='健', prob='0.00268'),
#   Word(word='術', prob='0.00268'),
#   Word(word='啟', prob='0.00268'),
#   Word(word='積', prob='0.00268'),
#   Word(word='課', prob='0.00268'),
#   Word(word='時', prob='0.00268'),
#   Word(word='再', prob='0.00268'),
#   Word(word='團', prob='0.00268'),
#   Word(word='法', prob='0.00268'),
#   Word(word='即', prob='0.00268'),
#   Word(word='以', prob='0.00268'),
#   Word(word='階', prob='0.00268'),
#   Word(word='人', prob='0.00268'),
#   Word(word='已', prob='0.00268'),
#   Word(word='雖', prob='0.00268'),
#   Word(word='研', prob='0.00268'),
#   Word(word='不', prob='0.00268'),
#   Word(word='水', prob='0.00268'),
#   Word(word='預', prob='0.00268'),
#   Word(word='或', prob='0.00268'),
#   Word(word='企', prob='0.00268'),
#   Word(word='旨', prob='0.00268'),
#   Word(word='一', prob='0.00268'),
#   Word(word='發', prob='0.00268'),
#   Word(word='八', prob='0.00268'),
#   Word(word='擔', prob='0.00268'),
#   Word(word='至', prob='0.00268'),
#   Word(word='體', prob='0.00268'),
#   Word(word='深', prob='0.00268'),
#   Word(word='且', prob='0.00268'),
#   Word(word='鄭', prob='0.00268'),
#   Word(word='設', prob='0.00268'),
#   Word(word='興', prob='0.00268'),
#   Word(word='推', prob='0.00268'),
#   Word(word='獲', prob='0.00268'),
#   Word(word='打', prob='0.00268'),
#   Word(word='分', prob='0.00268'),
#   Word(word='相', prob='0.00268'),
#   Word(word='旁', prob='0.00268'),
#   Word(word='具', prob='0.00268'),
#   Word(word='同', prob='0.00268'),
#   Word(word='端', prob='0.00268'),
#   Word(word='綜', prob='0.00268'),
#   Word(word='室', prob='0.00268'),
#   Word(word='主', prob='0.00268'),
#   Word(word='士', prob='0.00268'),
#   Word(word='策', prob='0.00268'),
#   Word(word='作', prob='0.00268'),
#   Word(word='有', prob='0.00268'),
#   Word(word='音', prob='0.00268'),
#   Word(word='因', prob='0.00268'),
#   Word(word='共', prob='0.00268'),
#   Word(word='文', prob='0.00268'),
#   Word(word='資', prob='0.00268'),
#   Word(word='元', prob='0.00268'),
#   Word(word='應', prob='0.00268'),
#   Word(word='攜', prob='0.00268'),
#   Word(word='任', prob='0.00268')],
#  '學週': [Word(word='年', prob='1')],
#  '週年': [Word(word='慶', prob='0.25'),
#   Word(word='校', prob='0.131'),
#   Word(word='紀', prob='0.0595'),
#   Word(word='鄭', prob='0.0476'),
#   Word(word='聖', prob='0.0357'),
#   Word(word='廟', prob='0.0357'),
#   Word(word='祈', prob='0.0357'),
#   Word(word='全', prob='0.0357'),
#   Word(word='暨', prob='0.0357'),
#   Word(word='釋', prob='0.0238'),
#   Word(word='公', prob='0.0238'),
#   Word(word='在', prob='0.0238'),
#   Word(word='能', prob='0.0119'),
#   Word(word='感', prob='0.0119'),
#   Word(word='九', prob='0.0119'),
#   Word(word='舉', prob='0.0119'),
#   Word(word='生', prob='0.0119'),
#   Word(word='高', prob='0.0119'),
#   Word(word='授', prob='0.0119'),
#   Word(word='由', prob='0.0119'),
#   Word(word='特', prob='0.0119'),
#   Word(word='屆', prob='0.0119'),
#   Word(word='發', prob='0.0119'),
#   Word(word='月', prob='0.0119'),
#   Word(word='紅', prob='0.0119'),
#   Word(word='社', prob='0.0119'),
#   Word(word='桃', prob='0.0119'),
#   Word(word='為', prob='0.0119'),
#   Word(word='仁', prob='0.0119'),
#   Word(word='金', prob='0.0119'),
#   Word(word='瑤', prob='0.0119'),
#   Word(word='的', prob='0.0119'),
#   Word(word='莊', prob='0.0119'),
#   Word(word='館', prob='0.0119')],
#  '年校': [Word(word='慶', prob='0.917'), Word(word='園', prob='0.0833')],
#  '校慶': [Word(word='運', prob='0.188'),
#   Word(word='園', prob='0.125'),
#   Word(word='時', prob='0.0625'),
#   Word(word='也', prob='0.0625'),
#   Word(word='鄭', prob='0.0625'),
#   Word(word='並', prob='0.0625'),
#   Word(word='今', prob='0.0625'),
#   Word(word='相', prob='0.0625'),
#   Word(word='籌', prob='0.0625'),
#   Word(word='活', prob='0.0625'),
#   Word(word='有', prob='0.0625'),
#   Word(word='啟', prob='0.0625'),
#   Word(word='王', prob='0.0625')],
#  '慶王': [Word(word='副', prob='1')],
#  '王副': [Word(word='局', prob='0.533'),
#   Word(word='市', prob='0.267'),
#   Word(word='理', prob='0.0667'),
#   Word(word='縣', prob='0.0667'),
#   Word(word='院', prob='0.0667')],
#  '副市': [Word(word='長', prob='1')],
#  '市長': [Word(word='表', prob='0.187'),
#   Word(word='鄭', prob='0.12'),
#   Word(word='指', prob='0.0995'),
#   Word(word='說', prob='0.0992'),
#   Word(word='也', prob='0.0918'),
#   Word(word='提', prob='0.0543'),
#   Word(word='談', prob='0.0498'),
#   Word(word='進', prob='0.0187'),
#   Word(word='張', prob='0.018'),
#   Word(word='強', prob='0.015'),
#   Word(word='感', prob='0.0113'),
#   Word(word='並', prob='0.00922'),
#   Word(word='今', prob='0.00744'),
#   Word(word='出', prob='0.00729'),
#   Word(word='特', prob='0.00699'),
#   Word(word='與', prob='0.00684'),
#   Word(word='補', prob='0.00625'),
#   Word(word='任', prob='0.0061'),
#   Word(word='在', prob='0.0055'),
#   Word(word='期', prob='0.00535'),
#   Word(word='回', prob='0.00521'),
#   Word(word='的', prob='0.00491'),
#   Word(word='年', prob='0.00491'),
#   Word(word='後', prob='0.00476'),
#   Word(word='分', prob='0.00431'),
#   Word(word='李', prob='0.00431'),
#   Word(word='及', prob='0.00416'),
#   Word(word='另', prob='0.00342'),
#   Word(word='亦', prob='0.00342'),
#   Word(word='為', prob='0.00312'),
#   Word(word='頒', prob='0.00283'),
#   Word(word='參', prob='0.00268'),
#   Word(word='視', prob='0.00268'),
#   Word(word='首', prob='0.00253'),
#   Word(word='對', prob='0.00253'),
#   Word(word='一', prob='0.00253'),
#   Word(word='肯', prob='0.00253'),
#   Word(word='鼓', prob='0.00238'),
#   Word(word='候', prob='0.00223'),
#   Word(word='邀', prob='0.00208'),
#   Word(word='高', prob='0.00208'),
#   Word(word='於', prob='0.00208'),
#   Word(word='是', prob='0.00208'),
#   Word(word='向', prob='0.00208'),
#   Word(word='王', prob='0.00208'),
#   Word(word='接', prob='0.00193'),
#   Word(word='盼', prob='0.00193'),
#   Word(word='以', prob='0.00193'),
#   Word(word='林', prob='0.00178'),
#   Word(word='上', prob='0.00178'),
#   Word(word='除', prob='0.00164'),
#   Word(word='最', prob='0.00164'),
#   Word(word='蘇', prob='0.00164'),
#   Word(word='代', prob='0.00134'),
#   Word(word='桃', prob='0.00134'),
#   Word(word='恭', prob='0.00119'),
#   Word(word='擔', prob='0.00119'),
#   Word(word='更', prob='0.00119'),
#   Word(word='祈', prob='0.00119'),
#   Word(word='率', prob='0.00119'),
#   Word(word='將', prob='0.00119'),
#   Word(word='陪', prob='0.00119'),
#   Word(word='盃', prob='0.00119'),
#   Word(word='之', prob='0.00104'),
#   Word(word='同', prob='0.00104'),
#   Word(word='前', prob='0.000892'),
#   Word(word='完', prob='0.000892'),
#   Word(word='市', prob='0.000892'),
#   Word(word='祝', prob='0.000892'),
#   Word(word='介', prob='0.000892'),
#   Word(word='認', prob='0.000892'),
#   Word(word='呼', prob='0.000892'),
#   Word(word='讓', prob='0.000892'),
#   Word(word='曾', prob='0.000744'),
#   Word(word='官', prob='0.000744'),
#   Word(word='施', prob='0.000744'),
#   Word(word='領', prob='0.000744'),
#   Word(word='贈', prob='0.000744'),
#   Word(word='慰', prob='0.000744'),
#   Word(word='因', prob='0.000744'),
#   Word(word='歡', prob='0.000744'),
#   Word(word='帶', prob='0.000744'),
#   Word(word='勉', prob='0.000744'),
#   Word(word='至', prob='0.000744'),
#   Word(word='隨', prob='0.000744'),
#   Word(word='再', prob='0.000744'),
#   Word(word='致', prob='0.000744'),
#   Word(word='則', prob='0.000595'),
#   Word(word='推', prob='0.000595'),
#   Word(word='加', prob='0.000595'),
#   Word(word='所', prob='0.000595'),
#   Word(word='陳', prob='0.000595'),
#   Word(word='者', prob='0.000595'),
#   Word(word='或', prob='0.000595'),
#   Word(word='時', prob='0.000595'),
#   Word(word='宣', prob='0.000595'),
#   Word(word='這', prob='0.000595'),
#   Word(word='親', prob='0.000595'),
#   Word(word='逐', prob='0.000595'),
#   Word(word='承', prob='0.000446'),
#   Word(word='希', prob='0.000446'),
#   Word(word='打', prob='0.000446'),
#   Word(word='會', prob='0.000446'),
#   Word(word='力', prob='0.000446'),
#   Word(word='共', prob='0.000446'),
#   Word(word='八', prob='0.000446'),
#   Word(word='大', prob='0.000446'),
#   Word(word='積', prob='0.000446'),
#   Word(word='已', prob='0.000446'),
#   Word(word='透', prob='0.000446'),
#   Word(word='舉', prob='0.000446'),
#   Word(word='實', prob='0.000446'),
#   Word(word='都', prob='0.000446'),
#   Word(word='不', prob='0.000446'),
#   Word(word='獲', prob='0.000446'),
#   Word(word='未', prob='0.000446'),
#   Word(word='羅', prob='0.000446'),
#   Word(word='落', prob='0.000446'),
#   Word(word='主', prob='0.000446'),
#   Word(word='春', prob='0.000446'),
#   Word(word='建', prob='0.000446'),
#   Word(word='照', prob='0.000446'),
#   Word(word='針', prob='0.000446'),
#   Word(word='細', prob='0.000446'),
#   Word(word='訪', prob='0.000446'),
#   Word(word='選', prob='0.000446'),
#   Word(word='卸', prob='0.000446'),
#   Word(word='現', prob='0.000446'),
#   Word(word='和', prob='0.000446'),
#   Word(word='就', prob='0.000297'),
#   Word(word='重', prob='0.000297'),
#   Word(word='持', prob='0.000297'),
#   Word(word='盡', prob='0.000297'),
#   Word(word='應', prob='0.000297'),
#   Word(word='把', prob='0.000297'),
#   Word(word='協', prob='0.000297'),
#   Word(word='能', prob='0.000297'),
#   Word(word='誠', prob='0.000297'),
#   Word(word='香', prob='0.000297'),
#   Word(word='日', prob='0.000297'),
#   Word(word='護', prob='0.000297'),
#   Word(word='中', prob='0.000297'),
#   Word(word='專', prob='0.000297'),
#   Word(word='體', prob='0.000297'),
#   Word(word='暨', prob='0.000297'),
#   Word(word='見', prob='0.000297'),
#   Word(word='請', prob='0.000297'),
#   Word(word='侯', prob='0.000297'),
#   Word(word='工', prob='0.000297'),
#   Word(word='澄', prob='0.000297'),
#   Word(word='越', prob='0.000297'),
#   Word(word='允', prob='0.000297'),
#   Word(word='鳴', prob='0.000297'),
#   Word(word='相', prob='0.000297'),
#   Word(word='發', prob='0.000297'),
#   Word(word='滿', prob='0.000297'),
#   Word(word='短', prob='0.000297'),
#   Word(word='巡', prob='0.000297'),
#   Word(word='有', prob='0.000297'),
#   Word(word='要', prob='0.000297'),
#   Word(word='赴', prob='0.000297'),
#   Word(word='霍', prob='0.000297'),
#   Word(word='本', prob='0.000297'),
#   Word(word='交', prob='0.000297'),
#   Word(word='萬', prob='0.000297'),
#   Word(word='蔣', prob='0.000297'),
#   Word(word='留', prob='0.000297'),
#   Word(word='議', prob='0.000297'),
#   Word(word='謝', prob='0.000297'),
#   Word(word='初', prob='0.000297'),
#   Word(word='讚', prob='0.000297'),
#   Word(word='室', prob='0.000297'),
#   Word(word='用', prob='0.000297'),
#   Word(word='長', prob='0.000297'),
#   Word(word='執', prob='0.000297'),
#   Word(word='競', prob='0.000297'),
#   Word(word='克', prob='0.000297'),
#   Word(word='心', prob='0.000149'),
#   Word(word='等', prob='0.000149'),
#   Word(word='支', prob='0.000149'),
#   Word(word='涓', prob='0.000149'),
#   Word(word='奠', prob='0.000149'),
#   Word(word='導', prob='0.000149'),
#   Word(word='庇', prob='0.000149'),
#   Word(word='攜', prob='0.000149'),
#   Word(word='結', prob='0.000149'),
#   Word(word='守', prob='0.000149'),
#   Word(word='合', prob='0.000149'),
#   Word(word='化', prob='0.000149'),
#   Word(word='須', prob='0.000149'),
#   Word(word='活', prob='0.000149'),
#   Word(word='從', prob='0.000149'),
#   Word(word='甫', prob='0.000149'),
#   Word(word='個', prob='0.000149'),
#   Word(word='揮', prob='0.000149'),
#   Word(word='若', prob='0.000149'),
#   Word(word='願', prob='0.000149'),
#   Word(word='到', prob='0.000149'),
#   Word(word='航', prob='0.000149'),
#   Word(word='受', prob='0.000149'),
#   Word(word='閉', prob='0.000149'),
#   Word(word='均', prob='0.000149'),
#   Word(word='揭', prob='0.000149'),
#   Word(word='做', prob='0.000149'),
#   Word(word='竭', prob='0.000149'),
#   Word(word='號', prob='0.000149'),
#   Word(word='即', prob='0.000149'),
#   Word(word='思', prob='0.000149'),
#   Word(word='探', prob='0.000149'),
#   Word(word='改', prob='0.000149'),
#   Word(word='可', prob='0.000149'),
#   Word(word='引', prob='0.000149'),
#   Word(word='手', prob='0.000149'),
#   Word(word='孩', prob='0.000149'),
#   Word(word='看', prob='0.000149'),
#   Word(word='保', prob='0.000149'),
#   Word(word='過', prob='0.000149'),
#   Word(word='民', prob='0.000149'),
#   Word(word='拜', prob='0.000149'),
#   Word(word='極', prob='0.000149'),
#   Word(word='幫', prob='0.000149'),
#   Word(word='收', prob='0.000149'),
#   Word(word='勝', prob='0.000149'),
#   Word(word='賣', prob='0.000149'),
#   Word(word='預', prob='0.000149'),
#   Word(word='往', prob='0.000149'),
#   Word(word='先', prob='0.000149'),
#   Word(word='壯', prob='0.000149'),
#   Word(word='點', prob='0.000149'),
#   Word(word='新', prob='0.000149'),
#   Word(word='融', prob='0.000149'),
#   Word(word='但', prob='0.000149'),
#   Word(word='趙', prob='0.000149'),
#   Word(word='簡', prob='0.000149'),
#   Word(word='島', prob='0.000149'),
#   Word(word='簽', prob='0.000149'),
#   Word(word='形', prob='0.000149'),
#   Word(word='稱', prob='0.000149'),
#   Word(word='開', prob='0.000149'),
#   Word(word='品', prob='0.000149'),
#   Word(word='兩', prob='0.000149'),
#   Word(word='拚', prob='0.000149'),
#   Word(word='而', prob='0.000149'),
#   Word(word='游', prob='0.000149'),
#   Word(word='總', prob='0.000149'),
#   Word(word='陸', prob='0.000149'),
#   Word(word='示', prob='0.000149'),
#   Word(word='跨', prob='0.000149'),
#   Word(word='爭', prob='0.000149'),
#   Word(word='連', prob='0.000149'),
#   Word(word='核', prob='0.000149'),
#   Word(word='儀', prob='0.000149'),
#   Word(word='傳', prob='0.000149'),
#   Word(word='徐', prob='0.000149'),
#   Word(word='暢', prob='0.000149'),
#   Word(word='擴', prob='0.000149'),
#   Word(word='召', prob='0.000149'),
#   Word(word='父', prob='0.000149'),
#   Word(word='象', prob='0.000149'),
#   Word(word='供', prob='0.000149'),
#   Word(word='熟', prob='0.000149'),
#   Word(word='尤', prob='0.000149'),
#   Word(word='仍', prob='0.000149'),
#   Word(word='興', prob='0.000149'),
#   Word(word='優', prob='0.000149'),
#   Word(word='政', prob='0.000149'),
#   Word(word='公', prob='0.000149'),
#   Word(word='池', prob='0.000149'),
#   Word(word='小', prob='0.000149'),
#   Word(word='烈', prob='0.000149'),
#   Word(word='必', prob='0.000149'),
#   Word(word='華', prob='0.000149'),
#   Word(word='全', prob='0.000149'),
#   Word(word='台', prob='0.000149'),
#   Word(word='賴', prob='0.000149'),
#   Word(word='延', prob='0.000149'),
#   Word(word='努', prob='0.000149'),
#   Word(word='義', prob='0.000149'),
#   Word(word='沒', prob='0.000149')],
#  '長肯': [Word(word='定', prob='1')],
#  '肯定': [Word(word='鄭', prob='0.122'),
#   Word(word='桃', prob='0.061'),
#   Word(word='市', prob='0.0457'),
#   Word(word='相', prob='0.0244'),
#   Word(word='今', prob='0.0244'),
#   Word(word='包', prob='0.0213'),
#   Word(word='此', prob='0.0213'),
#   Word(word='在', prob='0.0152'),
#   Word(word='獲', prob='0.0152'),
#   Word(word='與', prob='0.0152'),
#   Word(word='同', prob='0.0152'),
#   Word(word='也', prob='0.0122'),
#   Word(word='這', prob='0.0122'),
#   Word(word='的', prob='0.0122'),
#   Word(word='其', prob='0.0122'),
#   Word(word='並', prob='0.0122'),
#   Word(word='企', prob='0.00915'),
#   Word(word='警', prob='0.00915'),
#   Word(word='林', prob='0.00915'),
#   Word(word='新', prob='0.00915'),
#   Word(word='陳', prob='0.00915'),
#   Word(word='而', prob='0.00915'),
#   Word(word='榮', prob='0.00915'),
#   Word(word='大', prob='0.00915'),
#   Word(word='成', prob='0.00915'),
#   Word(word='是', prob='0.00915'),
#   Word(word='代', prob='0.00915'),
#   Word(word='他', prob='0.00915'),
#   Word(word='第', prob='0.00915'),
#   Word(word='本', prob='0.00915'),
#   Word(word='年', prob='0.0061'),
#   Word(word='有', prob='0.0061'),
#   Word(word='展', prob='0.0061'),
#   Word(word='張', prob='0.0061'),
#   Word(word='龍', prob='0.0061'),
#   Word(word='參', prob='0.0061'),
#   Word(word='</s>', prob='0.0061'),
#   Word(word='未', prob='0.0061'),
#   Word(word='最', prob='0.0061'),
#   Word(word='以', prob='0.0061'),
#   Word(word='公', prob='0.0061'),
#   Word(word='莊', prob='0.0061'),
#   Word(word='不', prob='0.0061'),
#   Word(word='各', prob='0.0061'),
#   Word(word='另', prob='0.0061'),
#   Word(word='外', prob='0.0061'),
#   Word(word='青', prob='0.0061'),
#   Word(word='特', prob='0.0061'),
#   Word(word='工', prob='0.0061'),
#   Word(word='因', prob='0.0061'),
#   Word(word='學', prob='0.0061'),
#   Word(word='為', prob='0.0061'),
#   Word(word='每', prob='0.0061'),
#   Word(word='交', prob='0.0061'),
#   Word(word='選', prob='0.0061'),
#   Word(word='更', prob='0.0061'),
#   Word(word='賴', prob='0.00305'),
#   Word(word='支', prob='0.00305'),
#   Word(word='經', prob='0.00305'),
#   Word(word='目', prob='0.00305'),
#   Word(word='可', prob='0.00305'),
#   Word(word='多', prob='0.00305'),
#   Word(word='蔡', prob='0.00305'),
#   Word(word='長', prob='0.00305'),
#   Word(word='街', prob='0.00305'),
#   Word(word='項', prob='0.00305'),
#   Word(word='政', prob='0.00305'),
#   Word(word='雖', prob='0.00305'),
#   Word(word='如', prob='0.00305'),
#   Word(word='去', prob='0.00305'),
#   Word(word='美', prob='0.00305'),
#   Word(word='無', prob='0.00305'),
#   Word(word='將', prob='0.00305'),
#   Word(word='水', prob='0.00305'),
#   Word(word='蘇', prob='0.00305'),
#   Word(word='感', prob='0.00305'),
#   Word(word='針', prob='0.00305'),
#   Word(word='所', prob='0.00305'),
#   Word(word='聯', prob='0.00305'),
#   Word(word='李', prob='0.00305'),
#   Word(word='溪', prob='0.00305'),
#   Word(word='館', prob='0.00305'),
#   Word(word='老', prob='0.00305'),
#   Word(word='質', prob='0.00305'),
#   Word(word='透', prob='0.00305'),
#   Word(word='社', prob='0.00305'),
#   Word(word='日', prob='0.00305'),
#   Word(word='擔', prob='0.00305'),
#   Word(word='足', prob='0.00305'),
#   Word(word='建', prob='0.00305'),
#   Word(word='父', prob='0.00305'),
#   Word(word='且', prob='0.00305'),
#   Word(word='被', prob='0.00305'),
#   Word(word='強', prob='0.00305'),
#   Word(word='分', prob='0.00305'),
#   Word(word='明', prob='0.00305'),
#   Word(word='沈', prob='0.00305'),
#   Word(word='尤', prob='0.00305'),
#   Word(word='人', prob='0.00305'),
#   Word(word='慎', prob='0.00305'),
#   Word(word='顯', prob='0.00305'),
#   Word(word='已', prob='0.00305'),
#   Word(word='受', prob='0.00305'),
#   Word(word='地', prob='0.00305'),
#   Word(word='藉', prob='0.00305'),
#   Word(word='芋', prob='0.00305'),
#   Word(word='辦', prob='0.00305'),
#   Word(word='優', prob='0.00305'),
#   Word(word='核', prob='0.00305'),
#   Word(word='環', prob='0.00305'),
#   Word(word='財', prob='0.00305'),
#   Word(word='縣', prob='0.00305'),
#   Word(word='但', prob='0.00305'),
#   Word(word='台', prob='0.00305'),
#   Word(word='曲', prob='0.00305'),
#   Word(word='家', prob='0.00305'),
#   Word(word='完', prob='0.00305'),
#   Word(word='瑋', prob='0.00305'),
#   Word(word='開', prob='0.00305'),
#   Word(word='期', prob='0.00305'),
#   Word(word='小', prob='0.00305'),
#   Word(word='梁', prob='0.00305'),
#   Word(word='令', prob='0.00305'),
#   Word(word='及', prob='0.00305'),
#   Word(word='結', prob='0.00305'),
#   Word(word='希', prob='0.00305'),
#   Word(word='等', prob='0.00305'),
#   Word(word='普', prob='0.00305'),
#   Word(word='業', prob='0.00305'),
#   Word(word='之', prob='0.00305'),
#   Word(word='衛', prob='0.00305'),
#   Word(word='歐', prob='0.00305'),
#   Word(word='霄', prob='0.00305'),
#   Word(word='對', prob='0.00305'),
#   Word(word='保', prob='0.00305'),
#   Word(word='議', prob='0.00305'),
#   Word(word='近', prob='0.00305'),
#   Word(word='位', prob='0.00305'),
#   Word(word='打', prob='0.00305'),
#   Word(word='落', prob='0.00305'),
#   Word(word='志', prob='0.00305'),
#   Word(word='施', prob='0.00305'),
#   Word(word='充', prob='0.00305'),
#   Word(word='羅', prob='0.00305'),
#   Word(word='疫', prob='0.00305')],
#  '定學': [Word(word='術', prob='0.25'),
#   Word(word='界', prob='0.25'),
#   Word(word='校', prob='0.25'),
#   Word(word='生', prob='0.25')],
#  '學界': [Word(word='的', prob='0.182'),
#   Word(word='等', prob='0.0909'),
#   Word(word='嶄', prob='0.0909'),
#   Word(word='知', prob='0.0909'),
#   Word(word='需', prob='0.0909'),
#   Word(word='做', prob='0.0909'),
#   Word(word='委', prob='0.0909'),
#   Word(word='合', prob='0.0909'),
#   Word(word='培', prob='0.0909'),
#   Word(word='間', prob='0.0909')],
#  '界培': [Word(word='育', prob='1')],
#  '培育': [Word(word='出', prob='0.061'),
#   Word(word='優', prob='0.061'),
#   Word(word='基', prob='0.0488'),
#   Word(word='在', prob='0.0366'),
#   Word(word='原', prob='0.0366'),
#   Word(word='的', prob='0.0366'),
#   Word(word='人', prob='0.0244'),
#   Word(word='客', prob='0.0244'),
#   Word(word='計', prob='0.0244'),
#   Word(word='台', prob='0.0244'),
#   Word(word='位', prob='0.0244'),
#   Word(word='許', prob='0.0244'),
#   Word(word='團', prob='0.0244'),
#   Word(word='文', prob='0.0244'),
#   Word(word='超', prob='0.0244'),
#   Word(word='青', prob='0.0244'),
#   Word(word='家', prob='0.0122'),
#   Word(word='近', prob='0.0122'),
#   Word(word='區', prob='0.0122'),
#   Word(word='因', prob='0.0122'),
#   Word(word='相', prob='0.0122'),
#   Word(word='沒', prob='0.0122'),
#   Word(word='桃', prob='0.0122'),
#   Word(word='新', prob='0.0122'),
#   Word(word='最', prob='0.0122'),
#   Word(word='醫', prob='0.0122'),
#   Word(word='以', prob='0.0122'),
#   Word(word='等', prob='0.0122'),
#   Word(word='教', prob='0.0122'),
#   Word(word='風', prob='0.0122'),
#   Word(word='社', prob='0.0122'),
#   Word(word='藝', prob='0.0122'),
#   Word(word='有', prob='0.0122'),
#   Word(word='名', prob='0.0122'),
#   Word(word='公', prob='0.0122'),
#   Word(word='今', prob='0.0122'),
#   Word(word='及', prob='0.0122'),
#   Word(word='解', prob='0.0122'),
#   Word(word='甚', prob='0.0122'),
#   Word(word='充', prob='0.0122'),
#   Word(word='皆', prob='0.0122'),
#   Word(word='辦', prob='0.0122'),
#   Word(word='與', prob='0.0122'),
#   Word(word='搖', prob='0.0122'),
#   Word(word='孩', prob='0.0122'),
#   Word(word='導', prob='0.0122'),
#   Word(word='設', prob='0.0122'),
#   Word(word='離', prob='0.0122'),
#   Word(word='農', prob='0.0122'),
#   Word(word='逾', prob='0.0122'),
#   Word(word='非', prob='0.0122'),
#   Word(word='工', prob='0.0122'),
#   Word(word='半', prob='0.0122'),
#   Word(word='中', prob='0.0122'),
#   Word(word='規', prob='0.0122')],
#  '育人': [Word(word='員', prob='0.5'),
#   Word(word='才', prob='0.286'),
#   Word(word='力', prob='0.0714'),
#   Word(word='包', prob='0.0714'),
#   Word(word='文', prob='0.0714')],
#  '人才': [Word(word='培', prob='0.128'),
#   Word(word='服', prob='0.11'),
#   Word(word='的', prob='0.0642'),
#   Word(word='招', prob='0.0459'),
#   Word(word='及', prob='0.0367'),
#   Word(word='孵', prob='0.0275'),
#   Word(word='投', prob='0.0275'),
#   Word(word='讓', prob='0.0275'),
#   Word(word='鄭', prob='0.0275'),
#   Word(word='發', prob='0.0183'),
#   Word(word='獎', prob='0.0183'),
#   Word(word='期', prob='0.0183'),
#   Word(word='需', prob='0.0183'),
#   Word(word='並', prob='0.0183'),
#   Word(word='濟', prob='0.0183'),
#   Word(word='今', prob='0.0183'),
#   Word(word='提', prob='0.0183'),
#   Word(word='而', prob='0.0183'),
#   Word(word='交', prob='0.0183'),
#   Word(word='與', prob='0.0183'),
#   Word(word='推', prob='0.00917'),
#   Word(word='打', prob='0.00917'),
#   Word(word='龜', prob='0.00917'),
#   Word(word='充', prob='0.00917'),
#   Word(word='創', prob='0.00917'),
#   Word(word='相', prob='0.00917'),
#   Word(word='等', prob='0.00917'),
#   Word(word='共', prob='0.00917'),
#   Word(word='代', prob='0.00917'),
#   Word(word='密', prob='0.00917'),
#   Word(word='亦', prob='0.00917'),
#   Word(word='也', prob='0.00917'),
#   Word(word='輩', prob='0.00917'),
#   Word(word='老', prob='0.00917'),
#   Word(word='有', prob='0.00917'),
#   Word(word='林', prob='0.00917'),
#   Word(word='都', prob='0.00917'),
#   Word(word='帶', prob='0.00917'),
#   Word(word='來', prob='0.00917'),
#   Word(word='集', prob='0.00917'),
#   Word(word='以', prob='0.00917'),
#   Word(word='欠', prob='0.00917'),
#   Word(word='這', prob='0.00917'),
#   Word(word='庫', prob='0.00917'),
#   Word(word='桃', prob='0.00917'),
#   Word(word='為', prob='0.00917'),
#   Word(word='畢', prob='0.00917'),
#   Word(word='元', prob='0.00917'),
#   Word(word='賀', prob='0.00917'),
#   Word(word='紅', prob='0.00917'),
#   Word(word='導', prob='0.00917'),
#   Word(word='感', prob='0.00917'),
#   Word(word='降', prob='0.00917')],
#  '才帶': [Word(word='動', prob='1')],
#  '帶動': [Word(word='地', prob='0.113'),
#   Word(word='桃', prob='0.107'),
#   Word(word='大', prob='0.0734'),
#   Word(word='台', prob='0.0452'),
#   Word(word='新', prob='0.0395'),
#   Word(word='更', prob='0.0339'),
#   Word(word='整', prob='0.0282'),
#   Word(word='下', prob='0.0282'),
#   Word(word='產', prob='0.0282'),
#   Word(word='城', prob='0.0226'),
#   Word(word='社', prob='0.0226'),
#   Word(word='龜', prob='0.0169'),
#   Word(word='周', prob='0.0169'),
#   Word(word='中', prob='0.0169'),
#   Word(word='觀', prob='0.0169'),
#   Word(word='站', prob='0.0169'),
#   Word(word='運', prob='0.0169'),
#   Word(word='商', prob='0.0169'),
#   Word(word='人', prob='0.0169'),
#   Word(word='夜', prob='0.0169'),
#   Word(word='客', prob='0.0169'),
#   Word(word='市', prob='0.0113'),
#   Word(word='唱', prob='0.0113'),
#   Word(word='半', prob='0.0113'),
#   Word(word='草', prob='0.0113'),
#   Word(word='就', prob='0.0113'),
#   Word(word='青', prob='0.0113'),
#   Word(word='楊', prob='0.0113'),
#   Word(word='疫', prob='0.0113'),
#   Word(word='全', prob='0.0113'),
#   Word(word='未', prob='0.0113'),
#   Word(word='振', prob='0.0113'),
#   Word(word='生', prob='0.00565'),
#   Word(word='的', prob='0.00565'),
#   Word(word='之', prob='0.00565'),
#   Word(word='了', prob='0.00565'),
#   Word(word='區', prob='0.00565'),
#   Word(word='舊', prob='0.00565'),
#   Word(word='八', prob='0.00565'),
#   Word(word='成', prob='0.00565'),
#   Word(word='房', prob='0.00565'),
#   Word(word='平', prob='0.00565'),
#   Word(word='沿', prob='0.00565'),
#   Word(word='冷', prob='0.00565'),
#   Word(word='後', prob='0.00565'),
#   Word(word='消', prob='0.00565'),
#   Word(word='都', prob='0.00565'),
#   Word(word='上', prob='0.00565'),
#   Word(word='一', prob='0.00565'),
#   Word(word='跳', prob='0.00565'),
#   Word(word='富', prob='0.00565'),
#   Word(word='老', prob='0.00565'),
#   Word(word='和', prob='0.00565'),
#   Word(word='復', prob='0.00565'),
#   Word(word='小', prob='0.00565'),
#   Word(word='發', prob='0.00565'),
#   Word(word='年', prob='0.00565'),
#   Word(word='在', prob='0.00565'),
#   Word(word='極', prob='0.00565'),
#   Word(word='農', prob='0.00565'),
#   Word(word='首', prob='0.00565')],
#  '動桃': [Word(word='園', prob='0.811'),
#   Word(word='原', prob='0.1'),
#   Word(word='林', prob='0.0222'),
#   Word(word='線', prob='0.0222'),
#   Word(word='市', prob='0.0111'),
#   Word(word='金', prob='0.0111'),
#   Word(word='地', prob='0.0111'),
#   Word(word='運', prob='0.0111')],
#  '桃園': [Word(word='市', prob='0.313'),
#   Word(word='的', prob='0.044'),
#   Word(word='區', prob='0.0381'),
#   Word(word='在', prob='0.0195'),
#   Word(word='航', prob='0.0148'),
#   Word(word='是', prob='0.0142'),
#   Word(word='地', prob='0.0137'),
#   Word(word='醫', prob='0.0126'),
#   Word(word='鐵', prob='0.011'),
#   Word(word='新', prob='0.00992'),
#   Word(word='升', prob='0.00961'),
#   Word(word='捷', prob='0.0091'),
#   Word(word='國', prob='0.00828'),
#   Word(word='大', prob='0.00787'),
#   Word(word='成', prob='0.00726'),
#   Word(word='好', prob='0.00695'),
#   Word(word='也', prob='0.00634'),
#   Word(word='推', prob='0.00614'),
#   Word(word='各', prob='0.00593'),
#   Word(word='站', prob='0.00593'),
#   Word(word='觀', prob='0.00562'),
#   Word(word='有', prob='0.00542'),
#   Word(word='農', prob='0.00532'),
#   Word(word='社', prob='0.00532'),
#   Word(word='人', prob='0.00511'),
#   Word(word='分', prob='0.00501'),
#   Word(word='燈', prob='0.0046'),
#   Word(word='長', prob='0.0045'),
#   Word(word='會', prob='0.00429'),
#   Word(word='機', prob='0.00419'),
#   Word(word='今', prob='0.00419'),
#   Word(word='閩', prob='0.00419'),
#   Word(word='自', prob='0.00409'),
#   Word(word='中', prob='0.00409'),
#   Word(word='共', prob='0.00389'),
#   Word(word='管', prob='0.00389'),
#   Word(word='北', prob='0.00378'),
#   Word(word='為', prob='0.00378'),
#   Word(word='哥', prob='0.00378'),
#   Word(word='高', prob='0.00378'),
#   Word(word='特', prob='0.00368'),
#   Word(word='萬', prob='0.00368'),
#   Word(word='發', prob='0.00368'),
#   Word(word='公', prob='0.00358'),
#   Word(word='設', prob='0.00358'),
#   Word(word='疫', prob='0.00348'),
#   Word(word='城', prob='0.00348'),
#   Word(word='不', prob='0.00348'),
#   Word(word='最', prob='0.00348'),
#   Word(word='更', prob='0.00348'),
#   Word(word='重', prob='0.00337'),
#   Word(word='與', prob='0.00337'),
#   Word(word='已', prob='0.00327'),
#   Word(word='擁', prob='0.00327'),
#   Word(word='工', prob='0.00307'),
#   Word(word='全', prob='0.00307'),
#   Word(word='原', prob='0.00297'),
#   Word(word='藝', prob='0.00286'),
#   Word(word='交', prob='0.00286'),
#   Word(word='目', prob='0.00286'),
#   Word(word='持', prob='0.00276'),
#   Word(word='年', prob='0.00276'),
#   Word(word='青', prob='0.00276'),
#   Word(word='家', prob='0.00276'),
#   Word(word='陽', prob='0.00276'),
#   Word(word='首', prob='0.00256'),
#   Word(word='海', prob='0.00256'),
#   Word(word='三', prob='0.00256'),
#   Word(word='巨', prob='0.00245'),
#   Word(word='煉', prob='0.00235'),
#   Word(word='客', prob='0.00235'),
#   Word(word='所', prob='0.00235'),
#   Word(word='總', prob='0.00235'),
#   Word(word='生', prob='0.00235'),
#   Word(word='電', prob='0.00225'),
#   Word(word='將', prob='0.00225'),
#   Word(word='未', prob='0.00225'),
#   Word(word='第', prob='0.00225'),
#   Word(word='教', prob='0.00225'),
#   Word(word='產', prob='0.00225'),
#   Word(word='及', prob='0.00215'),
#   Word(word='整', prob='0.00205'),
#   Word(word='建', prob='0.00205'),
#   Word(word='專', prob='0.00205'),
#   Word(word='蓮', prob='0.00194'),
#   Word(word='多', prob='0.00194'),
#   Word(word='永', prob='0.00194'),
#   Word(word='台', prob='0.00194'),
#   Word(word='車', prob='0.00194'),
#   Word(word='作', prob='0.00194'),
#   Word(word='打', prob='0.00194'),
#   Word(word='財', prob='0.00184'),
#   Word(word='棒', prob='0.00184'),
#   Word(word='附', prob='0.00184'),
#   Word(word='歲', prob='0.00174'),
#   Word(word='經', prob='0.00174'),
#   Word(word='近', prob='0.00174'),
#   Word(word='舉', prob='0.00164'),
#   Word(word='則', prob='0.00164'),
#   Word(word='桃', prob='0.00164'),
#   Word(word='縣', prob='0.00164'),
#   Word(word='文', prob='0.00153'),
#   Word(word='進', prob='0.00153'),
#   Word(word='榮', prob='0.00143'),
#   Word(word='率', prob='0.00143'),
#   Word(word='爭', prob='0.00143'),
#   Word(word='防', prob='0.00143'),
#   Word(word='都', prob='0.00143'),
#   Word(word='展', prob='0.00143'),
#   Word(word='正', prob='0.00143'),
#   Word(word='約', prob='0.00143'),
#   Word(word='每', prob='0.00133'),
#   Word(word='果', prob='0.00133'),
#   Word(word='可', prob='0.00133'),
#   Word(word='能', prob='0.00133'),
#   Word(word='本', prob='0.00133'),
#   Word(word='埤', prob='0.00133'),
#   Word(word='並', prob='0.00123'),
#   Word(word='積', prob='0.00123'),
#   Word(word='平', prob='0.00123'),
#   Word(word='負', prob='0.00123'),
#   Word(word='具', prob='0.00123'),
#   Word(word='八', prob='0.00123'),
#   Word(word='警', prob='0.00123'),
#   Word(word='開', prob='0.00123'),
#   Word(word='過', prob='0.00123'),
#   Word(word='科', prob='0.00123'),
#   Word(word='景', prob='0.00123'),
#   Word(word='隊', prob='0.00112'),
#   Word(word='除', prob='0.00112'),
#   Word(word='提', prob='0.00112'),
#   Word(word='內', prob='0.00112'),
#   Word(word='休', prob='0.00112'),
#   Word(word='一', prob='0.00112'),
#   Word(word='於', prob='0.00112'),
#   Word(word='亞', prob='0.00112'),
#   Word(word='獲', prob='0.00112'),
#   Word(word='佛', prob='0.00102'),
#   Word(word='參', prob='0.00102'),
#   Word(word='企', prob='0.00102'),
#   Word(word='投', prob='0.00102'),
#   Word(word='守', prob='0.00102'),
#   Word(word='創', prob='0.00102'),
#   Word(word='營', prob='0.00102'),
#   Word(word='以', prob='0.00102'),
#   Word(word='另', prob='0.00102'),
#   Word(word='學', prob='0.00102'),
#   Word(word='蘆', prob='0.00092'),
#   Word(word='魚', prob='0.00092'),
#   Word(word='秉', prob='0.00092'),
#   Word(word='代', prob='0.00092'),
#   Word(word='個', prob='0.00092'),
#   Word(word='夏', prob='0.00092'),
#   Word(word='軌', prob='0.00092'),
#   Word(word='合', prob='0.00092'),
#   Word(word='石', prob='0.00092'),
#   Word(word='居', prob='0.00092'),
#   Word(word='至', prob='0.00092'),
#   Word(word='半', prob='0.00092'),
#   Word(word='就', prob='0.00092'),
#   Word(word='龍', prob='0.00092'),
#   Word(word='變', prob='0.000818'),
#   Word(word='張', prob='0.000818'),
#   Word(word='基', prob='0.000818'),
#   Word(word='女', prob='0.000818'),
#   Word(word='無', prob='0.000818'),
#   Word(word='智', prob='0.000818'),
#   Word(word='鄉', prob='0.000818'),
#   Word(word='盃', prob='0.000818'),
#   Word(word='優', prob='0.000818'),
#   Word(word='上', prob='0.000818'),
#   Word(word='雖', prob='0.000818'),
#   Word(word='處', prob='0.000818'),
#   Word(word='跨', prob='0.000818'),
#   Word(word='因', prob='0.000818'),
#   Word(word='帶', prob='0.000818'),
#   Word(word='累', prob='0.000818'),
#   Word(word='郡', prob='0.000818'),
#   Word(word='之', prob='0.000818'),
#   Word(word='巡', prob='0.000818'),
#   Word(word='鄭', prob='0.000716'),
#   Word(word='兒', prob='0.000716'),
#   Word(word='廠', prob='0.000716'),
#   Word(word='綠', prob='0.000716'),
#   Word(word='號', prob='0.000716'),
#   Word(word='看', prob='0.000716'),
#   Word(word='非', prob='0.000716'),
#   Word(word='實', prob='0.000716'),
#   Word(word='夜', prob='0.000716'),
#   Word(word='館', prob='0.000716'),
#   Word(word='落', prob='0.000716'),
#   Word(word='占', prob='0.000716'),
#   Word(word='即', prob='0.000716'),
#   Word(word='旅', prob='0.000716'),
#   Word(word='出', prob='0.000716'),
#   Word(word='環', prob='0.000716'),
#   Word(word='讓', prob='0.000716'),
#   Word(word='致', prob='0.000716'),
#   Word(word='從', prob='0.000716'),
#   Word(word='親', prob='0.000716'),
#   Word(word='樂', prob='0.000716'),
#   Word(word='店', prob='0.000614'),
#   Word(word='歷', prob='0.000614'),
#   Word(word='空', prob='0.000614'),
#   Word(word='水', prob='0.000614'),
#   Word(word='這', prob='0.000614'),
#   Word(word='健', prob='0.000614'),
#   Word(word='殯', prob='0.000614'),
#   Word(word='四', prob='0.000614'),
#   Word(word='百', prob='0.000614'),
#   Word(word='忠', prob='0.000614'),
#   Word(word='事', prob='0.000614'),
#   Word(word='志', prob='0.000614'),
#   Word(word='韭', prob='0.000614'),
#   Word(word='花', prob='0.000614'),
#   Word(word='轉', prob='0.000614'),
#   Word(word='南', prob='0.000614'),
#   Word(word='包', prob='0.000614'),
#   Word(word='璞', prob='0.000614'),
#   Word(word='運', prob='0.000614'),
#   Word(word='月', prob='0.000614'),
#   Word(word='律', prob='0.000614'),
#   Word(word='體', prob='0.000511'),
#   Word(word='方', prob='0.000511'),
#   Word(word='土', prob='0.000511'),
#   Word(word='富', prob='0.000511'),
#   Word(word='垃', prob='0.000511'),
#   Word(word='輕', prob='0.000511'),
#   Word(word='透', prob='0.000511'),
#   Word(word='風', prob='0.000511'),
#   Word(word='選', prob='0.000511'),
#   Word(word='街', prob='0.000511'),
#   Word(word='得', prob='0.000511'),
#   Word(word='仍', prob='0.000511'),
#   Word(word='位', prob='0.000511'),
#   Word(word='治', prob='0.000511'),
#   Word(word='蓬', prob='0.000511'),
#   Word(word='繡', prob='0.000511'),
#   Word(word='深', prob='0.000511'),
#   Word(word='等', prob='0.000511'),
#   Word(word='火', prob='0.000511'),
#   Word(word='辦', prob='0.000511'),
#   Word(word='團', prob='0.000511'),
#   Word(word='金', prob='0.000511'),
#   Word(word='強', prob='0.000409'),
#   Word(word='畜', prob='0.000409'),
#   Word(word='和', prob='0.000409'),
#   Word(word='相', prob='0.000409'),
#   Word(word='結', prob='0.000409'),
#   Word(word='主', prob='0.000409'),
#   Word(word='補', prob='0.000409'),
#   Word(word='亦', prob='0.000409'),
#   Word(word='僅', prob='0.000409'),
#   Word(word='債', prob='0.000409'),
#   Word(word='領', prob='0.000409'),
#   Word(word='間', prob='0.000409'),
#   Word(word='幸', prob='0.000409'),
#   Word(word='如', prob='0.000409'),
#   Word(word='藍', prob='0.000409'),
#   Word(word='預', prob='0.000409'),
#   Word(word='再', prob='0.000409'),
#   Word(word='段', prob='0.000409'),
#   Word(word='雲', prob='0.000409'),
#   Word(word='此', prob='0.000409'),
#   Word(word='山', prob='0.000409'),
#   Word(word='小', prob='0.000409'),
#   Word(word='曾', prob='0.000409'),
#   Word(word='鮮', prob='0.000409'),
#   Word(word='當', prob='0.000409'),
#   Word(word='被', prob='0.000409'),
#   Word(word='確', prob='0.000307'),
#   Word(word='挺', prob='0.000307'),
#   Word(word='先', prob='0.000307'),
#   Word(word='珍', prob='0.000307'),
#   Word(word='著', prob='0.000307'),
#   Word(word='信', prob='0.000307'),
#   Word(word='保', prob='0.000307'),
#   Word(word='普', prob='0.000307'),
#   Word(word='技', prob='0.000307'),
#   Word(word='期', prob='0.000307'),
#   Word(word='唯', prob='0.000307'),
#   Word(word='昨', prob='0.000307'),
#   Word(word='改', prob='0.000307'),
#   Word(word='追', prob='0.000307'),
#   Word(word='異', prob='0.000307'),
#   Word(word='彩', prob='0.000307'),
#   Word(word='聖', prob='0.000307'),
#   Word(word='育', prob='0.000307'),
#   Word(word='救', prob='0.000307'),
#   Word(word='河', prob='0.000307'),
#   Word(word='採', prob='0.000307'),
#   Word(word='崖', prob='0.000307'),
#   Word(word='努', prob='0.000307'),
#   Word(word='老', prob='0.000307'),
#   Word(word='模', prob='0.000307'),
#   Word(word='許', prob='0.000307'),
#   Word(word='玄', prob='0.000307'),
#   Word(word='而', prob='0.000307'),
#   Word(word='府', prob='0.000307'),
#   Word(word='慈', prob='0.000307'),
#   Word(word='神', prob='0.000307'),
#   Word(word='益', prob='0.000307'),
#   Word(word='皆', prob='0.000307'),
#   Word(word='舊', prob='0.000307'),
#   Word(word='行', prob='0.000307'),
#   Word(word='往', prob='0.000307'),
#   Word(word='繼', prob='0.000307'),
#   Word(word='依', prob='0.000307'),
#   Word(word='咖', prob='0.000307'),
#   Word(word='規', prob='0.000307'),
#   Word(word='增', prob='0.000307'),
#   Word(word='遊', prob='0.000307'),
#   Word(word='現', prob='0.000307'),
#   Word(word='超', prob='0.000307'),
#   Word(word='豬', prob='0.000307'),
#   Word(word='低', prob='0.000307'),
#   Word(word='到', prob='0.000307'),
#   Word(word='數', prob='0.000307'),
#   Word(word='他', prob='0.000307'),
#   Word(word='母', prob='0.000307'),
#   Word(word='宗', prob='0.000307'),
#   Word(word='境', prob='0.000307'),
#   Word(word='登', prob='0.000307'),
#   Word(word='污', prob='0.000205'),
#   Word(word='子', prob='0.000205'),
#   Word(word='鼓', prob='0.000205'),
#   Word(word='穩', prob='0.000205'),
#   Word(word='托', prob='0.000205'),
#   Word(word='走', prob='0.000205'),
#   Word(word='黑', prob='0.000205'),
#   Word(word='既', prob='0.000205'),
#   Word(word='支', prob='0.000205'),
#   Word(word='測', prob='0.000205'),
#   Word(word='充', prob='0.000205'),
#   Word(word='商', prob='0.000205'),
#   Word(word='做', prob='0.000205'),
#   Word(word='呼', prob='0.000205'),
#   Word(word='計', prob='0.000205'),
#   Word(word='點', prob='0.000205'),
#   Word(word='越', prob='0.000205'),
#   Word(word='安', prob='0.000205'),
#   Word(word='連', prob='0.000205'),
#   Word(word='且', prob='0.000205'),
#   Word(word='施', prob='0.000205'),
#   Word(word='散', prob='0.000205'),
#   Word(word='邁', prob='0.000205'),
#   Word(word='擴', prob='0.000205'),
#   Word(word='敬', prob='0.000205'),
#   Word(word='製', prob='0.000205'),
#   Word(word='沿', prob='0.000205'),
#   Word(word='鎮', prob='0.000205'),
#   Word(word='便', prob='0.000205'),
#   Word(word='肉', prob='0.000205'),
#   Word(word='勞', prob='0.000205'),
#   Word(word='道', prob='0.000205'),
#   Word(word='試', prob='0.000205'),
#   Word(word='外', prob='0.000205'),
#   Word(word='照', prob='0.000205'),
#   Word(word='移', prob='0.000205'),
#   Word(word='億', prob='0.000205'),
#   Word(word='名', prob='0.000205'),
#   Word(word='順', prob='0.000205'),
#   Word(word='弱', prob='0.000205'),
#   Word(word='仙', prob='0.000205'),
#   Word(word='少', prob='0.000205'),
#   Word(word='美', prob='0.000205'),
#   Word(word='紅', prob='0.000205'),
#   Word(word='減', prob='0.000205'),
#   Word(word='衛', prob='0.000205'),
#   Word(word='用', prob='0.000205'),
#   Word(word='雙', prob='0.000205'),
#   Word(word='或', prob='0.000205'),
#   Word(word='跳', prob='0.000205'),
#   Word(word='敢', prob='0.000205'),
#   Word(word='服', prob='0.000205'),
#   Word(word='屢', prob='0.000205'),
#   Word(word='射', prob='0.000205'),
#   Word(word='興', prob='0.000205'),
#   Word(word='春', prob='0.000205'),
# ...
#   Word(word='核', prob='0.00143'),
#   Word(word='耐', prob='0.00143'),
#   Word(word='打', prob='0.00143'),
#   Word(word='媒', prob='0.00143'),
#   Word(word='智', prob='0.00143'),
#   Word(word='餌', prob='0.00143'),
#   Word(word='是', prob='0.00143'),
#   Word(word='謝', prob='0.00143'),
#   Word(word='健', prob='0.00143'),
#   Word(word='提', prob='0.00143'),
#   Word(word='違', prob='0.00143'),
#   Word(word='箱', prob='0.00143'),
#   Word(word='衍', prob='0.00143'),
#   Word(word='上', prob='0.00143'),
#   Word(word='針', prob='0.00143'),
#   Word(word='靈', prob='0.00143'),
#   Word(word='橫', prob='0.00143'),
#   Word(word='一', prob='0.00143'),
#   Word(word='溪', prob='0.00143'),
#   Word(word='由', prob='0.00143')],
#  '理市': [Word(word='府', prob='0.375'),
#   Word(word='長', prob='0.25'),
#   Word(word='政', prob='0.125'),
#   Word(word='民', prob='0.0625'),
#   Word(word='內', prob='0.0625'),
#   Word(word='集', prob='0.0625'),
#   Word(word='地', prob='0.0625')],
#  '內寄': [Word(word='養', prob='1')],
#  '養服': [Word(word='務', prob='1')],
#  '務截': [Word(word='至', prob='1')],
#  '截至': [Word(word='月', prob='0.38'),
#   Word(word='今', prob='0.282'),
#   Word(word='目', prob='0.172'),
#   Word(word='昨', prob='0.0675'),
#   Word(word='年', prob='0.0552'),
#   Word(word='去', prob='0.0245'),
#   Word(word='下', prob='0.0123'),
#   Word(word='日', prob='0.00613')],
#  '年月': [Word(word='日', prob='0.255'),
#   Word(word='完', prob='0.189'),
#   Word(word='底', prob='0.0937'),
#   Word(word='開', prob='0.0386'),
#   Word(word='竣', prob='0.0293'),
#   Word(word='起', prob='0.0258'),
#   Word(word='至', prob='0.0164'),
#   Word(word='動', prob='0.0164'),
#   Word(word='啟', prob='0.0152'),
#   Word(word='通', prob='0.0141'),
#   Word(word='已', prob='0.0117'),
#   Word(word='獲', prob='0.0117'),
#   Word(word='桃', prob='0.00937'),
#   Word(word='與', prob='0.0082'),
#   Word(word='初', prob='0.0082'),
#   Word(word='正', prob='0.0082'),
#   Word(word='市', prob='0.00703'),
#   Word(word='前', prob='0.00703'),
#   Word(word='成', prob='0.00703'),
#   Word(word='舉', prob='0.00703'),
#   Word(word='全', prob='0.00703'),
#   Word(word='發', prob='0.00585'),
#   Word(word='中', prob='0.00585'),
#   Word(word='可', prob='0.00585'),
#   Word(word='順', prob='0.00585'),
#   Word(word='取', prob='0.00585'),
#   Word(word='辦', prob='0.00585'),
#   Word(word='將', prob='0.00468'),
#   Word(word='為', prob='0.00468'),
#   Word(word='進', prob='0.00468'),
#   Word(word='交', prob='0.00468'),
#   Word(word='及', prob='0.00468'),
#   Word(word='份', prob='0.00351'),
#   Word(word='也', prob='0.00351'),
#   Word(word='行', prob='0.00351'),
#   Word(word='落', prob='0.00351'),
#   Word(word='止', prob='0.00351'),
#   Word(word='推', prob='0.00351'),
#   Word(word='試', prob='0.00234'),
#   Word(word='提', prob='0.00234'),
#   Word(word='由', prob='0.00234'),
#   Word(word='施', prob='0.00234'),
#   Word(word='函', prob='0.00234'),
#   Word(word='重', prob='0.00234'),
#   Word(word='公', prob='0.00234'),
#   Word(word='有', prob='0.00234'),
#   Word(word='台', prob='0.00234'),
#   Word(word='契', prob='0.00234'),
#   Word(word='統', prob='0.00234'),
#   Word(word='點', prob='0.00234'),
#   Word(word='今', prob='0.00234'),
#   Word(word='後', prob='0.00234'),
#   Word(word='展', prob='0.00234'),
#   Word(word='供', prob='0.00234'),
#   Word(word='上', prob='0.00234'),
#   Word(word='在', prob='0.00234'),
#   Word(word='的', prob='0.00234'),
#   Word(word='核', prob='0.00234'),
#   Word(word='以', prob='0.00234'),
#   Word(word='曾', prob='0.00234'),
#   Word(word='共', prob='0.00234'),
#   Word(word='累', prob='0.00234'),
#   Word(word='整', prob='0.00234'),
#   Word(word='平', prob='0.00117'),
#   Word(word='紫', prob='0.00117'),
#   Word(word='媒', prob='0.00117'),
#   Word(word='就', prob='0.00117'),
#   Word(word='亦', prob='0.00117'),
#   Word(word='經', prob='0.00117'),
#   Word(word='設', prob='0.00117'),
#   Word(word='得', prob='0.00117'),
#   Word(word='疫', prob='0.00117'),
#   Word(word='即', prob='0.00117'),
#   Word(word='號', prob='0.00117'),
#   Word(word='更', prob='0.00117'),
#   Word(word='召', prob='0.00117'),
#   Word(word='跟', prob='0.00117'),
#   Word(word='世', prob='0.00117'),
#   Word(word='均', prob='0.00117'),
#   Word(word='下', prob='0.00117'),
#   Word(word='用', prob='0.00117'),
#   Word(word='耀', prob='0.00117'),
#   Word(word='盛', prob='0.00117'),
#   Word(word='衛', prob='0.00117'),
#   Word(word='教', prob='0.00117'),
#   Word(word='層', prob='0.00117'),
#   Word(word='工', prob='0.00117'),
#   Word(word='申', prob='0.00117'),
#   Word(word='移', prob='0.00117'),
#   Word(word='於', prob='0.00117'),
#   Word(word='農', prob='0.00117'),
#   Word(word='高', prob='0.00117'),
#   Word(word='體', prob='0.00117'),
#   Word(word='北', prob='0.00117'),
#   Word(word='按', prob='0.00117'),
#   Word(word='延', prob='0.00117'),
#   Word(word='特', prob='0.00117'),
#   Word(word='年', prob='0.00117'),
#   Word(word='招', prob='0.00117'),
#   Word(word='陳', prob='0.00117'),
#   Word(word='逐', prob='0.00117'),
#   Word(word='新', prob='0.00117'),
#   Word(word='宣', prob='0.00117'),
#   Word(word='收', prob='0.00117'),
#   Word(word='率', prob='0.00117'),
#   Word(word='當', prob='0.00117'),
#   Word(word='鄭', prob='0.00117'),
#   Word(word='第', prob='0.00117'),
#   Word(word='嘉', prob='0.00117'),
#   Word(word='月', prob='0.00117'),
#   Word(word='復', prob='0.00117'),
#   Word(word='環', prob='0.00117'),
#   Word(word='連', prob='0.00117'),
#   Word(word='間', prob='0.00117'),
#   Word(word='龜', prob='0.00117'),
#   Word(word='接', prob='0.00117'),
#   Word(word='打', prob='0.00117'),
#   Word(word='配', prob='0.00117'),
#   Word(word='熱', prob='0.00117'),
#   Word(word='造', prob='0.00117'),
#   Word(word='他', prob='0.00117'),
#   Word(word='實', prob='0.00117'),
#   Word(word='創', prob='0.00117'),
#   Word(word='土', prob='0.00117'),
#   Word(word='增', prob='0.00117'),
#   Word(word='機', prob='0.00117'),
#   Word(word='榮', prob='0.00117'),
#   Word(word='會', prob='0.00117')],
#  '月止': [Word(word='桃', prob='0.667'), Word(word='已', prob='0.333')],
#  '止已': [Word(word='有', prob='0.6'),
#   Word(word='服', prob='0.2'),
#   Word(word='完', prob='0.2')],
#  '已服': [Word(word='務', prob='1')],
#  '務超': [Word(word='過', prob='1')],
#  '超過': [Word(word='萬', prob='0.314'),
#   Word(word='億', prob='0.108'),
#   Word(word='個', prob='0.0523'),
#   Word(word='成', prob='0.0458'),
#   Word(word='年', prob='0.0359'),
#   Word(word='百', prob='0.0327'),
#   Word(word='公', prob='0.0294'),
#   Word(word='人', prob='0.0261'),
#   Word(word='家', prob='0.0229'),
#   Word(word='千', prob='0.0229'),
#   Word(word='小', prob='0.0196'),
#   Word(word='件', prob='0.0163'),
#   Word(word='組', prob='0.0163'),
#   Word(word='處', prob='0.0163'),
#   Word(word='元', prob='0.0163'),
#   Word(word='座', prob='0.0098'),
#   Word(word='名', prob='0.0098'),
#   Word(word='所', prob='0.00654'),
#   Word(word='的', prob='0.00654'),
#   Word(word='上', prob='0.00654'),
#   Word(word='新', prob='0.00654'),
#   Word(word='桃', prob='0.00654'),
#   Word(word='項', prob='0.00654'),
#   Word(word='戶', prob='0.00654'),
#   Word(word='其', prob='0.00654'),
#   Word(word='部', prob='0.00654'),
#   Word(word='法', prob='0.00654'),
#   Word(word='間', prob='0.00327'),
#   Word(word='起', prob='0.00327'),
#   Word(word='堂', prob='0.00327'),
#   Word(word='市', prob='0.00327'),
#   Word(word='九', prob='0.00327'),
#   Word(word='一', prob='0.00327'),
#   Word(word='道', prob='0.00327'),
#   Word(word='同', prob='0.00327'),
#   Word(word='竹', prob='0.00327'),
#   Word(word='往', prob='0.00327'),
#   Word(word='站', prob='0.00327'),
#   Word(word='次', prob='0.00327'),
#   Word(word='每', prob='0.00327'),
#   Word(word='四', prob='0.00327'),
#   Word(word='案', prob='0.00327'),
#   Word(word='八', prob='0.00327'),
#   Word(word='為', prob='0.00327'),
#   Word(word='多', prob='0.00327'),
#   Word(word='縣', prob='0.00327'),
#   Word(word='兆', prob='0.00327'),
#   Word(word='之', prob='0.00327'),
#   Word(word='台', prob='0.00327'),
#   Word(word='全', prob='0.00327'),
#   Word(word='月', prob='0.00327'),
#   Word(word='國', prob='0.00327'),
#   Word(word='時', prob='0.00327'),
#   Word(word='噸', prob='0.00327'),
#   Word(word='場', prob='0.00327'),
#   Word(word='條', prob='0.00327'),
#   Word(word='歲', prob='0.00327'),
#   Word(word='三', prob='0.00327'),
#   Word(word='位', prob='0.00327'),
#   Word(word='棟', prob='0.00327'),
#   Word(word='株', prob='0.00327'),
#   Word(word='當', prob='0.00327'),
#   Word(word='趟', prob='0.00327'),
#   Word(word='桌', prob='0.00327'),
#   Word(word='份', prob='0.00327'),
#   Word(word='通', prob='0.00327'),
#   Word(word='更', prob='0.00327'),
#   Word(word='另', prob='0.00327'),
#   Word(word='且', prob='0.00327'),
#   Word(word='十', prob='0.00327')],
#  '過名': [Word(word='學', prob='0.333'),
#   Word(word='兒', prob='0.333'),
#   Word(word='警', prob='0.333')],
#  '名兒': [Word(word='童', prob='0.75'), Word(word='子', prob='0.25')],
#  '兒童': [Word(word='疫', prob='0.189'),
#   Word(word='遊', prob='0.0619'),
#   Word(word='莫', prob='0.0495'),
#   Word(word='玩', prob='0.0495'),
#   Word(word='之', prob='0.0464'),
#   Word(word='醫', prob='0.0433'),
#   Word(word='大', prob='0.0402'),
#   Word(word='劇', prob='0.0279'),
#   Word(word='美', prob='0.0279'),
#   Word(word='專', prob='0.0248'),
#   Word(word='及', prob='0.0217'),
#   Word(word='藝', prob='0.0217'),
#   Word(word='表', prob='0.0217'),
#   Word(word='課', prob='0.0155'),
#   Word(word='病', prob='0.0155'),
#   Word(word='施', prob='0.0155'),
#   Word(word='公', prob='0.0155'),
#   Word(word='接', prob='0.0155'),
#   Word(word='也', prob='0.0124'),
#   Word(word='第', prob='0.0124'),
#   Word(word='冒', prob='0.0124'),
#   Word(word='桃', prob='0.00929'),
#   Word(word='劑', prob='0.00929'),
#   Word(word='保', prob='0.00929'),
#   Word(word='駕', prob='0.00929'),
#   Word(word='的', prob='0.00929'),
#   Word(word='夜', prob='0.00929'),
#   Word(word='參', prob='0.00619'),
#   Word(word='發', prob='0.00619'),
#   Word(word='人', prob='0.00619'),
#   Word(word='皆', prob='0.00619'),
#   Word(word='社', prob='0.00619'),
#   Word(word='尚', prob='0.00619'),
#   Word(word='學', prob='0.00619'),
#   Word(word='都', prob='0.00619'),
#   Word(word='滿', prob='0.00619'),
#   Word(word='由', prob='0.00619'),
#   Word(word='或', prob='0.00619'),
#   Word(word='加', prob='0.00619'),
#   Word(word='如', prob='0.00619'),
#   Word(word='晚', prob='0.0031'),
#   Word(word='共', prob='0.0031'),
#   Word(word='因', prob='0.0031'),
#   Word(word='打', prob='0.0031'),
#   Word(word='型', prob='0.0031'),
#   Word(word='適', prob='0.0031'),
#   Word(word='免', prob='0.0031'),
#   Word(word='友', prob='0.0031'),
#   Word(word='使', prob='0.0031'),
#   Word(word='為', prob='0.0031'),
#   Word(word='早', prob='0.0031'),
#   Word(word='閱', prob='0.0031'),
#   Word(word='漁', prob='0.0031'),
#   Word(word='運', prob='0.0031'),
#   Word(word='明', prob='0.0031'),
#   Word(word='秘', prob='0.0031'),
#   Word(word='生', prob='0.0031'),
#   Word(word='志', prob='0.0031'),
#   Word(word='婦', prob='0.0031'),
#   Word(word='看', prob='0.0031'),
#   Word(word='符', prob='0.0031'),
#   Word(word='托', prob='0.0031'),
#   Word(word='就', prob='0.0031'),
#   Word(word='完', prob='0.0031'),
#   Word(word='團', prob='0.0031'),
#   Word(word='谷', prob='0.0031'),
#   Word(word='走', prob='0.0031'),
#   Word(word='須', prob='0.0031'),
#   Word(word='卡', prob='0.0031'),
#   Word(word='體', prob='0.0031'),
#   Word(word='於', prob='0.0031'),
#   Word(word='腦', prob='0.0031'),
#   Word(word='暨', prob='0.0031'),
#   Word(word='盡', prob='0.0031'),
#   Word(word='樂', prob='0.0031'),
#   Word(word='仍', prob='0.0031'),
#   Word(word='健', prob='0.0031'),
#   Word(word='多', prob='0.0031'),
#   Word(word='意', prob='0.0031'),
#   Word(word='其', prob='0.0031')],
#  '童或': [Word(word='少', prob='0.333'),
#   Word(word='歲', prob='0.333'),
#   Word(word='可', prob='0.333')],
#  '或少': [Word(word='年', prob='1')],
#  '少年': [Word(word='活', prob='0.157'),
#   Word(word='培', prob='0.108'),
#   Word(word='交', prob='0.098'),
#   Word(word='之', prob='0.0588'),
#   Word(word='友', prob='0.0294'),
#   Word(word='的', prob='0.0294'),
#   Word(word='閱', prob='0.0294'),
#   Word(word='輕', prob='0.0196'),
#   Word(word='跆', prob='0.0196'),
#   Word(word='接', prob='0.0196'),
#   Word(word='發', prob='0.0196'),
#   Word(word='防', prob='0.0196'),
#   Word(word='反', prob='0.0098'),
#   Word(word='約', prob='0.0098'),
#   Word(word='三', prob='0.0098'),
#   Word(word='及', prob='0.0098'),
#   Word(word='組', prob='0.0098'),
#   Word(word='表', prob='0.0098'),
#   Word(word='第', prob='0.0098'),
#   Word(word='福', prob='0.0098'),
#   Word(word='人', prob='0.0098'),
#   Word(word='開', prob='0.0098'),
#   Word(word='則', prob='0.0098'),
#   Word(word='森', prob='0.0098'),
#   Word(word='階', prob='0.0098'),
#   Word(word='透', prob='0.0098'),
#   Word(word='創', prob='0.0098'),
#   Word(word='最', prob='0.0098'),
#   Word(word='探', prob='0.0098'),
#   Word(word='目', prob='0.0098'),
#   Word(word='族', prob='0.0098'),
#   Word(word='進', prob='0.0098'),
#   Word(word='熱', prob='0.0098'),
#   Word(word='今', prob='0.0098'),
#   Word(word='奇', prob='0.0098'),
#   Word(word='也', prob='0.0098'),
#   Word(word='空', prob='0.0098'),
#   Word(word='語', prob='0.0098'),
#   Word(word='施', prob='0.0098'),
#   Word(word='學', prob='0.0098'),
#   Word(word='社', prob='0.0098'),
#   Word(word='使', prob='0.0098'),
#   Word(word='謝', prob='0.0098'),
#   Word(word='動', prob='0.0098'),
#   Word(word='得', prob='0.0098'),
#   Word(word='為', prob='0.0098'),
#   Word(word='欲', prob='0.0098'),
#   Word(word='玖', prob='0.0098'),
#   Word(word='參', prob='0.0098'),
#   Word(word='警', prob='0.0098'),
#   Word(word='關', prob='0.0098'),
#   Word(word='整', prob='0.0098')],
#  '年目': [Word(word='前', prob='1')],
#  '前市': [Word(word='府', prob='0.914'),
#   Word(word='長', prob='0.0247'),
#   Word(word='內', prob='0.0247'),
#   Word(word='場', prob='0.0123'),
#   Word(word='民', prob='0.0123'),
#   Word(word='都', prob='0.0123')],
#  '少共': [Word(word='融', prob='0.667'), Word(word='計', prob='0.333')],
#  '共計': [Word(word='個', prob='0.0789'),
#   Word(word='約', prob='0.0746'),
#   Word(word='萬', prob='0.0746'),
#   Word(word='人', prob='0.0658'),
#   Word(word='家', prob='0.0439'),
#   Word(word='接', prob='0.0439'),
#   Word(word='位', prob='0.0439'),
#   Word(word='有', prob='0.0395'),
#   Word(word='件', prob='0.0263'),
#   Word(word='床', prob='0.0219'),
#   Word(word='戶', prob='0.0219'),
#   Word(word='名', prob='0.0219'),
#   Word(word='座', prob='0.0219'),
#   Word(word='可', prob='0.0175'),
#   Word(word='台', prob='0.0175'),
#   Word(word='規', prob='0.0175'),
#   Word(word='處', prob='0.0175'),
#   Word(word='提', prob='0.0175'),
#   Word(word='發', prob='0.0132'),
#   Word(word='元', prob='0.0132'),
#   Word(word='億', prob='0.0132'),
#   Word(word='組', prob='0.00877'),
#   Word(word='噸', prob='0.00877'),
#   Word(word='公', prob='0.00877'),
#   Word(word='間', prob='0.00877'),
#   Word(word='支', prob='0.00877'),
#   Word(word='天', prob='0.00877'),
#   Word(word='項', prob='0.00877'),
#   Word(word='表', prob='0.00877'),
#   Word(word='超', prob='0.00877'),
#   Word(word='設', prob='0.00877'),
#   Word(word='將', prob='0.00877'),
#   Word(word='里', prob='0.00877'),
#   Word(word='坪', prob='0.00877'),
#   Word(word='增', prob='0.00439'),
#   Word(word='完', prob='0.00439'),
#   Word(word='興', prob='0.00439'),
#   Word(word='起', prob='0.00439'),
#   Word(word='開', prob='0.00439'),
#   Word(word='大', prob='0.00439'),
#   Word(word='整', prob='0.00439'),
#   Word(word='三', prob='0.00439'),
#   Word(word='受', prob='0.00439'),
#   Word(word='退', prob='0.00439'),
#   Word(word='培', prob='0.00439'),
#   Word(word='在', prob='0.00439'),
#   Word(word='邀', prob='0.00439'),
#   Word(word='自', prob='0.00439'),
#   Word(word='近', prob='0.00439'),
#   Word(word='日', prob='0.00439'),
#   Word(word='遴', prob='0.00439'),
#   Word(word='要', prob='0.00439'),
#   Word(word='撥', prob='0.00439'),
#   Word(word='條', prob='0.00439'),
#   Word(word='場', prob='0.00439'),
#   Word(word='補', prob='0.00439'),
#   Word(word='展', prob='0.00439'),
#   Word(word='獲', prob='0.00439'),
#   Word(word='扣', prob='0.00439'),
#   Word(word='米', prob='0.00439'),
#   Word(word='棟', prob='0.00439'),
#   Word(word='推', prob='0.00439'),
#   Word(word='區', prob='0.00439'),
#   Word(word='編', prob='0.00439'),
#   Word(word='榮', prob='0.00439'),
#   Word(word='吸', prob='0.00439'),
#   Word(word='進', prob='0.00439'),
#   Word(word='簽', prob='0.00439'),
#   Word(word='兒', prob='0.00439'),
#   Word(word='斤', prob='0.00439'),
#   Word(word='隊', prob='0.00439'),
#   Word(word='道', prob='0.00439'),
#   Word(word='班', prob='0.00439'),
#   Word(word='一', prob='0.00439'),
#   Word(word='改', prob='0.00439')],
#  '計名': [Word(word='學', prob='0.286'),
#   Word(word='志', prob='0.143'),
#   Word(word='合', prob='0.143'),
#   Word(word='包', prob='0.143'),
#   Word(word='並', prob='0.143'),
#   Word(word='選', prob='0.143')],
#  ...}

# %%
text = '天下'
next_words = list(tri_prediction[text])[:5]
for next_word in next_words:
    print('next word: {}, probability: {}'.format(next_word.word, next_word.prob))
    
"""
next word: 仁, probability: 0.111
next word: 及, probability: 0.0741
next word: 地, probability: 0.0741
next word: 超, probability: 0.0741
next word: 文, probability: 0.0741
"""
# Out:
# next word: 雜, probability: 0.355
# next word: 午, probability: 0.129
# next word: 的, probability: 0.0968
# next word: 第, probability: 0.0968
# next word: 沒, probability: 0.0323
# '\nnext word: 仁, probability: 0.111\nnext word: 及, probability: 0.0741\nnext word: 地, probability: 0.0741\nnext word: 超, probability: 0.0741\nnext word: 文, probability: 0.0741\n'
